# %% [markdown]
# <a href="https://colab.research.google.com/github/mannodiarun/Purdue-MSE-497/blob/main/Read_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 1. Read data directly from uploaded csv file

import pandas as pd

data = pd.read_csv('material_properties.csv')

# %%
## Upload csv file, copy path to it, then read it as a pandas dataframe

data = pd.read_csv('/content/material_properties.csv')

# %%
data
# Out:
#                        Material  Tensile Strength (MPa)  Density (g/cm^3)  \
# 0              Aluminum 6061-T6                     310              2.70
# 1          Titanium (Ti-6Al-4V)                     950              4.43
# 2           Stainless Steel 304                     550              8.00
# 3                        Copper                     210              8.96
# 4                Magnesium AZ31                     250              1.78
# 5                        Nickel                     600              8.90
# 6                          Zinc                     120              7.14
# 7                   Inconel 718                    1240              8.19
# 8             Brass (70Cu-30Zn)                     350              8.50
# 9                      Tungsten                     550             19.30
# 10                         Lead                      15             11.34
# 11                     Chromium                     275              7.19
# ...

# %%
## 2. Read data from Github repo
## Go to Github repo, click on csv file, then "copy path". Put the path below in the !wget line.

import pandas as pd

# !wget https://github.com/mannodiarun/Purdue-MSE-497/blob/main/material_properties.csv
data = pd.read_csv('material_properties.csv')
# Out:
# --2025-02-12 19:55:56--  https://github.com/mannodiarun/Purdue-MSE-497/blob/main/material_properties.csv
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘material_properties.csv.4’
#
# material_properties     [ <=>                ] 227.61K  --.-KB/s    in 0.05s
#
# 2025-02-12 19:55:56 (4.49 MB/s) - ‘material_properties.csv.4’ saved [233073]

# %%
data
# Out:
#                        Material  Tensile Strength (MPa)  Density (g/cm^3)  \
# 0              Aluminum 6061-T6                     310              2.70
# 1          Titanium (Ti-6Al-4V)                     950              4.43
# 2           Stainless Steel 304                     550              8.00
# 3                        Copper                     210              8.96
# 4                Magnesium AZ31                     250              1.78
# 5                        Nickel                     600              8.90
# 6                          Zinc                     120              7.14
# 7                   Inconel 718                    1240              8.19
# 8             Brass (70Cu-30Zn)                     350              8.50
# 9                      Tungsten                     550             19.30
# 10                         Lead                      15             11.34
# 11                     Chromium                     275              7.19
# ...

# %%
## 3. Read data from Google Drive

import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

data = pd.read_csv('/content/drive/MyDrive/MSE-497-Code-Repository/Module-2/material_properties.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data
# Out:
#                        Material  Tensile Strength (MPa)  Density (g/cm^3)  \
# 0              Aluminum 6061-T6                     310              2.70
# 1          Titanium (Ti-6Al-4V)                     950              4.43
# 2           Stainless Steel 304                     550              8.00
# 3                        Copper                     210              8.96
# 4                Magnesium AZ31                     250              1.78
# 5                        Nickel                     600              8.90
# 6                          Zinc                     120              7.14
# 7                   Inconel 718                    1240              8.19
# 8             Brass (70Cu-30Zn)                     350              8.50
# 9                      Tungsten                     550             19.30
# 10                         Lead                      15             11.34
# 11                     Chromium                     275              7.19
# ...
